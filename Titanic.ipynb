# %% [markdown]
# <a href="https://colab.research.google.com/github/Mary7Magdalene/streamlittrial/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
titanic_data = pd.read_csv("/content/Titanic-Dataset.csv")

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#dropping columns
titanic_data = titanic_data.drop(columns = 'Cabin', axis = 1)

# %%
titanic_data = titanic_data.drop(columns = 'PassengerId', axis = 1)

# %%
#filling the missing values in age with mean
titanic_data['Age'] = titanic_data['Age'].fillna(titanic_data['Age'].mean())

# %%
#dropping the null values in the embarked column
titanic_data = titanic_data.drop(columns = 'Embarked', axis = 1)

# %%
titanic_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# dtype: int64

# %%
titanic_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare'],
#       dtype='object')

# %%
titanic_data.head(3)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare
# 0    male  22.0      1      0         A/5 21171   7.2500
# 1  female  38.0      1      0          PC 17599  71.2833
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250

# %%
#encoding the categorical columns
categorical_columns = ['Name','Sex','Ticket']
encoder = LabelEncoder()
for columns in categorical_columns:
  titanic_data[columns]=encoder.fit_transform(titanic_data[columns])

#normalizing the continious variables
#Instead of creating a new column, apply normalization directly to the existing columns
for column in ['Age','Fare','Parch','SibSp','Pclass']:
    titanic_data[column] = (titanic_data[column] - titanic_data[column].min()) / (titanic_data[column].max() - titanic_data[column].min())

titanic_data.head(3)
# Out:
#    Survived  Pclass  Name  Sex       Age  SibSp  Parch  Ticket      Fare
# 0         0     1.0   108    1  0.271174  0.125    0.0     523  0.014151
# 1         1     0.0   190    0  0.472229  0.125    0.0     596  0.139136
# 2         1     1.0   353    0  0.321438  0.000    0.0     669  0.015469

# %%
x= titanic_data.drop(columns = 'Survived', axis = 1)
y = titanic_data['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
#splitting the data into training and test sets
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
#fitting the model with the training set of data
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
print("{:.2f}".format(accuracy))
# Out:
# 0.81

# %%
classification_report =classification_report(y_test,y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       105
#            1       0.79      0.73      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179

# %%
import numpy as np
input_data = x[0,:]
input_data_reshaped = input_data.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
print(prediction)
# Out:
# [0]

# %%
if prediction ==0:
    print('The person died')
else:
    print('The person survived')
# Out:
# The person died

# %%
titanic_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# dtype: int64

# %%
import pickle

# %%
#saving the trained model using pickle
filename = 'Trained_model.pkl'
pickle.dump(model, open(filename,'wb'))
